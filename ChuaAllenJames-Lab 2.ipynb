# %% [markdown]
# 1A (Links to an external site.)
# Rectangle (Links to an external site.)
# 2 points (Links to an external site.)
# (int, int) -> None
#
# This function prints a solid rectangle composed of asterisks ("*").
# This rectangle should be of the specified width and the specified height.
# This function does not return any value; it simply prints the rectangle string.

# %%
def print_rectangle(width, height):
    i=0
    while i<height:
        j=0
        while j<width:
            print("*", end=" ")
            j+=1
        print()
        i+=1
    return
print_rectangle(2,3)

# %% [markdown]
# 1B (Links to an external site.)
# Hollow Rectangle (Links to an external site.)
# 3 points (Links to an external site.)
# (int, int) -> None
#
# This function prints a hollow rectangle composed of asterisks (*).
# The borders of this rectangle are composed of asterisks ("*").
# The insides of this rectangle are composed of spaces (" ").
# This rectangle should be of the specified width and the specified height.
# This function does not return any value; it simply prints the rectangle string.

# %%
def print_hollow_rectangle(width, height):
    i=1
    while i<=height:
        j=1
        while j<=width:
            if (j==1 or j==width or i==height or i==1):
                print("*", end=" ")
            else:
                print(" ", end=" ")   
            j+=1
        print()
        i+=1
    return

# %%
print_hollow_rectangle(3,4)

# %%
# GRADED FUNCTION
def print_hollow_rectangle(width, height):
    '''
    (int, int) -> None
    
    This function prints a hollow rectangle composed of asterisks (*).
    The borders of this rectangle are composed of asterisks ("*").
    The insides of this rectangle are composed of spaces (" ").
    This rectangle should be of the specified width and the specified height.
    This function does not return any value; it simply prints the rectangle string.
    '''
    
    rectangle_string = ""
    
    # Write your code below
    
    # End of code
    
    print(rectangle_string)

# %%
# GRADED FUNCTION
def caesar_encrypt(message, shift):
    '''
    (str, int) -> str
    
    This function encrypts a message using the Caesar cipher method.
    The Caesar cipher "shifts" each letter in a message to the right by a specified number.
    
    For example:
    
    encrypt('ABC', 2) -> 'CDE'
    
    In terms of ordinal positions in the alphabet, 'A' is 0, 'B' is 1, and 'C' is 2.
    Add the specified number to each of these values to receive 0 + 2 = 2, 2 + 2 = 4, and 3 + 2 = 5.
    Converting back to letters from numbers: 2 is 'C', 3 is 'D', and 4 is 'E'.
    
    Another example:
    
    encrypt('XYZ', 2) -> 'ZAB'
    
    In terms of ordinal positions in the alphabet, 'X' is 23, 'Y' is 24, and 'Z' is 25.
    Add the specified number to each to receive 25, 26, and 27 respectively.
    26 and 27 no longer fall in the range of alphabet numbers, so we need to "wrap" them around.
      Subtract 26 from 26 and 27 to receive 0 and 1.
    The final list of numbers is 25, 0, and 1.
    Converting back to letters from numbers: 25 is 'Z', 0 is 'A', and 1 is 'B'.
    
    You may find these functions helpful:
    chr() converts a Unicode integer value to a character (i.e. a letter).
      e.g. chr(65) -> 'A'
    ord() converts a character (i.e. a letter) to its Unicode integer value.
      e.g. ord('A') -> 65
      
    For your convenience:
    1. The message is composed entirely of capital letters. There will be no spaces or lower case letters.
    2. The shift number will be between 0 and 25.
    3. The alphabet is mapped such that A is 0 and Z is 25.
    '''
    
    output = ''
    
    for letter in message:
        convert1=(ord(letter)-65+shift) #to get the arrangement in 0-25
        convert2=convert1%26+65 #mod 26 to get A as 0
        newletter=chr(convert2)
        output=output+newletter
    return output

# %%
caesar_encrypt("ABC",3)

# %% [markdown]
# Vigenere Cipher (Links to an external site.)
# 4 points (Links to an external site.)
# (str, str) -> str
#
# This function encrypts a message using the Vigenere cipher method.
#
# The Vigenere cipher is an extension of the Caesar cipher method. Instead of using a uniform number, the Vigenere cipher uses a keyword to shift letters.
#
# Example:
#
# vigenere_encrypt('ABC', 'KEY') -> 'KFA'
#
# First, convert the message and the key to numbers.
# 'ABC' -> [0, 1, 2]
# 'KEY' -> [10, 4, 24]
# Second, add the respective numbers to each other.
# [0, 1, 2] + [10, 4, 24] = [10, 5, 26]
# Third, correct the numbers that do not fall within 0-25 by subtracting 26 until they fall within 0-25.
# [10, 5, 26] -> [10, 5, 0]
# Fourth, convert the numbers back to letters.
# [10, 5, 0] -> 'KFA'
#
# For your convenience:
#
# You are highly encouraged to use your Caesar cipher function from Item 2 in this item.
# You may assume that the key is the same length as the message.
# Bonus points:
#
# +2 (with a perfect base function) (all or nothing) if you adjust for the case that the key is shorter than the message. (e.g. "MEAMORE", "UEDA" -> "MEAMORE", "UEDAUED")

# %%
# GRADED FUNCTION
def vigenere_encrypt(message, keyword):
    '''
    (str, str) -> str
    
    This function encrypts a message using the Vigenere cipher method.
    
    The Vigenere cipher is an extension of the Caesar cipher method.
    Instead of using a uniform number, the Vigenere cipher uses a keyword to shift letters.
    
    Example:
    
    vigenere_encrypt('ABC', 'KEY') -> 'KFA'
    
    First, convert the message and the key to numbers.
    'ABC' -> [0, 1, 2]
    'KEY' -> [10, 4, 24]
    Second, add the respective numbers to each other.
    [0, 1, 2] + [10, 4, 24] = [10, 5, 26]
    Third, correct the numbers that do not fall within 0-25 by subtracting 26.
    [10, 5, 26] -> [10, 5, 0]
    Fourth, convert the numbers back to letters.
    [10, 5, 0] -> 'KFA'
    
    For your convenience:
    1. You are highly encouraged to use your Caesar cipher function from Item 2 in this item.
    2. You may assume that the key is the same length as the message.
    
    Bonus points:
    1. +2 (with a perfect base function) (all or nothing) if you adjust for the case that the key is 
      shorter than the message. (e.g. "MEAMORE", "UEDA" -> "MEAMORE", "UEDAUED")
    ''' 
    output = ''
    # Write your code below
    ml = []
    kl = []
    nl = []
    ol = []
    list(message)
    list(keyword)
    newkeyword = keyword
    minus = len(message)
    repeat = 0
    remainder = 0
    if minus > len(keyword):
        repeat = len(message)//len(keyword)
        remainder += len(message)%len(keyword)
    #print(repeat)
    #print(remainder)
    if len(message) > len(keyword):
        for i in range(0, repeat-1):
            newkeyword += keyword
        for i in range(0, remainder):
            newkeyword += keyword[i]
    #print(newkeyword)
    for i in range(0,len(message)):
        ml.append(ord(message[i])-65)
    #print(ml)
    for i in range(0, len(newkeyword)):
        kl.append(ord(newkeyword[i])-65)
    #print(kl)
    for i in range(0, len(ml)):
        nl.append(ml[i] + kl[i])
    for i in range(0, len(nl)):
        if (nl[i]) > 25:
            nl[i] = nl[i] - 26
        ol.append(chr(nl[i]+65))
    output = "".join(list(ol))
    # End of code
    return output

# %%
vigenere_encrypt("MEAMORE", "UEDA")
# Out:
# 'GIDMIVH'

# %% [markdown]
# 4 (Links to an external site.)
# Contact Tracing (Links to an external site.)
# 7 points (Links to an external site.)
# This function simulates tracing an infected person and marking people they come into contact with.
#
# Rules of the Game (Links to an external site.)
# The simulation starts with a single infected person (infected_person).
# The people in this game "move". These movements are represented by strings.
# Each person that an infected person comes into contact with will become infected in the next round.
# Conceptual demonstration (Links to an external site.)
# Initial infected = C
#
# Movements:
# 'JFHGIABECD'
# 'GAFJBCDIHE'
# 'FCGAEBIJDH'
#
# In the first round, C is next to E and D. E and D will thus be infected next round.
# In the second round:
# The list of infected: CDE
# C is adjacent to B and D
# D is adjacent to C and I
# E is adjacent to H
# B, I, and H will thus be new infected next round.
# In the third round:
# The list of infected: CDEBIH
# C is adjacent to F and G
# D is adjacent to J and H
# E is adjacent to A and B
# B is adjacent to E and I
# I is adjacent to B and J
# H is adjacent to D
# F, G, J, and A will thus be new infected next round, but there is no next round, so the list of infected for the next round will count as our "final" list of infected.
# The final list of infected: CDEBIHFGJA. This is basically every single element. Note that in Python, the final list of infected will look like this:
# ['C', 'D', 'E', 'B', 'I', 'H', 'F', 'G', 'J', 'A']
# Required (Links to an external site.)
# Write a function that takes an initial infected person as its first parameter and a list of movements as its second parameter. The function should return the final list of infected.
#
# Please note the following:
#
# Your solution must work for an arbitrary number of movements of an arbitrary number of elements. This means that your code must still work if we change the initial infected person or the movement list.
# There will be no duplicate elements.
# There will only ever be one initial infected person.
# Please comment your code. It will help us understand your logic, and it will help you get partial points on this item.

# %%
# SETUP. DO NOT EDIT THESE LINES.
sample_initial_infected_person = 'C'
sample_movement_list = ['LMcSEDJfZAqbWRUgYeurIdtzKoihOxBmkQjFlpvNwXyPnCasGHVT',
                         'ihpSPvorENDadfcyjnqlmgHWxTCKGIUkeOZzMJXYsuAwVbLRQBFt',
                         'qepTuMENGwDztARCImQhiJXfnWbcaVvyrLsZjdYKSFBHPoxglOkU']
# END OF SETUP.

# GRADED FUNCTION
def trace(initial_infected_person, movement_list):
    '''
    (str, [str]) -> [str]
    
    This function simulates tracing an infected person and marking people they come into contact with.
    
    '''
    final_list_of_infected = []

    infected=[]
    # Write your code below
    #adds initial infected in a list
    infected.append(initial_infected_person)
    for i in movement_list: #checks all the items
        infect=''.join(infected)
        for char in infect:
            position=i.find(char) #finds infected    
            if position==0:
                one=infected.append(i[position+1])
            elif position==(len(i)-1):
                two=infected.append(i[position-1])
            else:
                one=infected.append(i[position+1])
                two=infected.append(i[position-1])
    
    
    final_list_of_infected=set(infected)
    
    
    return final_list_of_infected

# %%
trace("C",['LMcSEDJfZAqbWRUgYeurIdtzKoihOxBmkQjFlpvNwXyPnCasGHVT',
                         'ihpSPvorENDadfcyjnqlmgHWxTCKGIUkeOZzMJXYsuAwVbLRQBFt',
                         'qepTuMENGwDztARCImQhiJXfnWbcaVvyrLsZjdYKSFBHPoxglOkU'])
# Out:
# {'C',
#  'D',
#  'I',
#  'K',
#  'R',
#  'S',
#  'T',
#  'V',
#  'W',
#  'Y',
#  'Z',
#  'a',
#  'c',
#  'd',
#  'e',
#  'f',
#  'j',
#  'n',
#  'p',
#  'q',
#  'u',
#  'w',
#  'z'}
